# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51514/2303a51514-batch-22/blob/main/lab-7.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
years = [1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020, 2024]
co2_emissions = [945, 1023, 1102, 1180, 1295, 1372, 1448, 1510, 1623, 1756, 1875, 1992, 2105, 2178]
plt.figure(figsize=(10, 6))
plt.plot(years, co2_emissions, marker='o', color='black', linestyle='-', linewidth=2)
plt.title("Global CO₂ Emissions Over Time", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("CO₂ Emissions (Million Metric Tons)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
if co2_emissions[-1] > co2_emissions[0]:
    print("✅ CO₂ emissions have increased over the years, indicating a growth trend.")
else:
    print("✅ CO₂ emissions have decreased over the years, indicating a reduction trend.")
# Out:
# ✅ CO₂ emissions have increased over the years, indicating a growth trend.

# %%
import matplotlib.pyplot as plt
exam_numbers = [1, 2, 3, 4, 5]
student_scores = [65, 70, 75, 80, 85]
plt.plot(exam_numbers, student_scores, marker='o', linestyle='-', color='black', label='Student Score')
plt.title("Student Performance Over Exams")
plt.xlabel("Exam Number")
plt.ylabel("Score")
plt.xticks(exam_numbers)
plt.yticks(range(0, 101, 10))
plt.grid(True)
plt.legend()
plt.show()
